# %% [markdown]
# # Model Development

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#importing the final csv file which was manuplated in 2 section
path='./final.csv'
df=pd.read_csv(path)
df.head()
# Out:
#       width  curb-weight  engine-size  horsepower  peak-rpm  price  \
# 0  0.890278         2548          130         111    5000.0  13495
# 1  0.890278         2548          130         111    5000.0  16500
# 2  0.909722         2823          152         154    5000.0  16500
# 3  0.919444         2337          109         102    5500.0  13950
# 4  0.922222         2824          136         115    5500.0  17450
#
#    city-L/100km  highway-L/100km horsepower-binned
# 0     11.190476         8.703704               low
# 1     11.190476         8.703704               low
# 2     12.368421         9.038462            medium
# 3      9.791667         7.833333               low
# 4     13.055556        10.681818               low

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Starting with simple linear regression
# <br>y = a+bx</br>
# <br>y is dependent variable</br>
# <br>x is independent variable</br>
# <br>a = intercept</br>
# <br>b = coefficient</br>

# %%
#importing the linear regression from sklearn
from sklearn.linear_model import LinearRegression

# %%
#creating the LinearRegression object
lm=LinearRegression()

# %%
#let's first try to implement simple linear regression using highway-L/100km
X=df[['highway-L/100km']]
Y=df['price']

# %%
#fit the values of X independent variable and Y dependent variable
lm.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#finding the output or values of Y predicted by our model
Yhat_slr=lm.predict(X)

# %%
#displaying the predicted values
Yhat_slr[0:5]
# Out:
# array([15485.52737455, 15485.52737455, 16643.34931414, 12475.19033163,
#        22327.2024721 ])

# %%
#intercept of the regression line
lm.intercept_
# Out:
# -14617.843054664616

# %%
#coefficient of the regression line
lm.coef_
# Out:
# array([3458.68511314])

# %%
#density plot to see the difference between the actual value and predicted value
plt.figure(figsize=(12,10))
ax1=sns.distplot(df['price'],hist=False,color='r',label='Actual Value')
sns.distplot(Yhat_slr,hist=False,color='b',label='Fitted Value',ax=ax1)
plt.title('Actual vs Fitted Value of Simple Linear Regression')
plt.xlabel('Price')
plt.show('Properties')
plt.close()

# %% [markdown]
# Simple linear regression model shows pretty good result

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# <br>y = a0+a1x1+a2x2..........+anxn</br>
# <br>y = dependent variable</br>
# <br>x1,x2,...,xn = independent variable</br>
# <br>a0 = intercept</br>
# <br>a1,a2,...,an = cofficient</br>

# %%
#selecting multiple columns for multiple regression model
Z=df[['curb-weight','engine-size','horsepower','highway-L/100km']]

# %%
lm.fit(Z,df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# -14382.161315163663

# %%
lm.coef_
# Out:
# array([  3.50153554,  85.32658561,  36.76149419, 498.91963877])

# %%
Y_hat_mlr=lm.predict(Z)

# %%
Y_hat_mlr[:5]
# Out:
# array([14055.18192433, 14055.18192433, 18643.05058857, 10759.40130978,
#        16667.53138368])

# %%
#density plot to see the difference between the actual value and predicted value
plt.figure(figsize=(12,10))
ax1=sns.distplot(df['price'],hist=False,color='r',label='Actual Value')
sns.distplot(Y_hat_mlr,hist=False,color='b',label='Fitted Value',ax=ax1)
plt.title('Actual vs Fitted Value of Multiple Linear Regression')
plt.xlabel('Price')
plt.show('Properties')
plt.close()

# %% [markdown]
# Multiple linear regression model good fits the data

# %% [markdown]
# # Polynomial Regression

# %%
#checking weather polynomial model can better fit the model 
x=df['highway-L/100km']
y=df['price']
f=np.polyfit(x,y,5)
p=np.poly1d(f)
p
# Out:
# poly1d([-2.02168213e+00,  1.02169330e+02, -2.01745849e+03,  1.96537082e+04,
#        -9.15629134e+04,  1.67663084e+05])

# %%
#taking 100 values between highway-L/100km minimum and maximum value
x_new=np.linspace(df['highway-L/100km'].min(),df['highway-L/100km'].max(),100)
#polynomial values of degree 5 of the new values
y_new=p(x_new)
plt.plot(x,y,'.',x_new,y_new,'-')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2)

# %%
z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 4)

# %%
z_pr.shape
# Out:
# (201, 15)

# %%
lm.fit(z_pr,df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_degree=lm.predict(z_pr)

# %%
#density plot to see the difference between the actual value and predicted linear value and predicted polynomial values
plt.figure(figsize=(12,10))
ax1=sns.distplot(df['price'],hist=False,color='r',label='Actual Value')
sns.distplot(Y_hat_mlr,hist=False,color='b',label='Fitted linear Value',ax=ax1)
sns.distplot(Y_degree,hist=False,color='g',label='Fitted poly Value',ax=ax1)
plt.title('Actual vs Linear Fitted vs Polynomialy Fitted Values')
plt.xlabel('Price')
plt.show('Properties')
plt.close()

# %% [markdown]
# above distribution plot shows that polynomial model fits the data perfectly as compair to multiple or simple linear regression model

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)

# %%
pipe.fit(Z,y)
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
ypipe=pipe.predict(Z)
ypipe[:5]
# Out:
# array([12396.25072589, 12396.25072589, 18427.88376418,  9983.16028344,
#        17552.23459066])

# %%
lm.fit(Z,df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# -14382.161315163663

# %%
lm.score(Z,df['price'])
# Out:
# 0.8118544998135149

# %%
Yhat=lm.predict(Z)

# %%
plt.figure(figsize=(12,10))
ax1=sns.distplot(df['price'],hist=False,color='r',label='Actual Value')
sns.distplot(Yhat,hist=False,color='b',label='Fitted Value',ax=ax1)
plt.title('Actual vs Fitted Value Using Pipeline')
plt.xlabel('Price')
plt.show('Properties')
plt.close()

# %%
price_data=df['price']

# %%
property_data=df.drop('price',axis=1)

# %%
property_data.head()
# Out:
#       width  curb-weight  engine-size  horsepower  peak-rpm  city-L/100km  \
# 0  0.890278         2548          130         111    5000.0     11.190476
# 1  0.890278         2548          130         111    5000.0     11.190476
# 2  0.909722         2823          152         154    5000.0     12.368421
# 3  0.919444         2337          109         102    5500.0      9.791667
# 4  0.922222         2824          136         115    5500.0     13.055556
#
#    highway-L/100km horsepower-binned
# 0         8.703704               low
# 1         8.703704               low
# 2         9.038462            medium
# 3         7.833333               low
# 4        10.681818               low

# %%
df.corr()
# Out:
#                     width  curb-weight  engine-size  horsepower  peak-rpm  \
# width            1.000000     0.866201     0.729436    0.614972 -0.245852
# curb-weight      0.866201     1.000000     0.849072    0.758001 -0.279350
# engine-size      0.729436     0.849072     1.000000    0.822636 -0.256753
# horsepower       0.614972     0.758001     0.822636    1.000000  0.107882
# peak-rpm        -0.245852    -0.279350    -0.256753    0.107882  1.000000
# price            0.751265     0.834415     0.872335    0.809729 -0.101542
# city-L/100km     0.673363     0.785353     0.745059    0.889454  0.115813
# highway-L/100km  0.736728     0.836921     0.783465    0.840695  0.017736
#
#                     price  city-L/100km  highway-L/100km
# width            0.751265      0.673363         0.736728
# curb-weight      0.834415      0.785353         0.836921
# engine-size      0.872335      0.745059         0.783465
# horsepower       0.809729      0.889454         0.840695
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
#spliting the data into test train
x_train,x_test,y_train,y_test=train_test_split(property_data,price_data,test_size=0.3,random_state=1)

# %%
#fitting the model with trainning data
lm.fit(x_train[['curb-weight','horsepower','highway-L/100km','engine-size']],y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
yhat_train=lm.predict(x_train[['curb-weight','horsepower','highway-L/100km','engine-size']])
yhat_train[:5]
# Out:
# array([30843.04480777,  6883.38615693,  7155.5339856 , 10203.69627802,
#          377.88434809])

# %%
#predicting the values of test data
yhat_test=lm.predict(x_test[['curb-weight','horsepower','highway-L/100km','engine-size']])
yhat_test[:5]
# Out:
# array([11153.03548363,  5949.80059591, 11256.99295547,  6989.50554729,
#        15490.84937134])

# %%
#density plot to see the difference between the actual train values and fitted train values
plt.figure(figsize=(12,10))
ax1=sns.distplot(y_train,hist=False,color='r',label='Actual Value')
sns.distplot(yhat_train,hist=False,color='b',label='Fitted Value',ax=ax1)
plt.title('Actual vs Fitted Value of train data in Linear Regression')
plt.xlabel('Price')
plt.show('Properties')
plt.close()

# %%
#density plot to see the difference between the actual test values and fitted test values
plt.figure(figsize=(12,10))
ax1=sns.distplot(y_test,hist=False,color='r',label='Actual Value')
sns.distplot(yhat_test,hist=False,color='b',label='Fitted Value',ax=ax1)
plt.title('Actual vs Fitted Value of test data in Linear Regression')
plt.xlabel('Price')
plt.show('Properties')
plt.close()

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# mean squared error of linear model

# %%
mean_squared_error(yhat_test,y_test)
# Out:
# 11505442.544890618

# %% [markdown]
# R2 value of linear model

# %%
lm.score(x_test[['curb-weight','horsepower','highway-L/100km','engine-size']],y_test)
# Out:
# 0.7681989074166417

# %% [markdown]
# # Polynomial Regression

# %%
#polynomial transform of test train data
poly=PolynomialFeatures(degree=3)

# %%
x_train_poly=poly.fit_transform(x_train[['curb-weight','engine-size','horsepower','highway-L/100km']])

# %%
x_test_poly=poly.fit_transform(x_test[['curb-weight','engine-size','horsepower','highway-L/100km']])

# %%
lm_poly=LinearRegression()

# %%
lm_poly.fit(x_train_poly,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_poly=lm_poly.predict(x_train_poly)

# %%
y_test_poly=lm_poly.predict(x_test_poly)

# %%
#density plot to see the difference between the actual value and polynomial filled values
plt.figure(figsize=(12,10))
ax1=sns.distplot(y_train,hist=False,color='r',label='Actual Value')
sns.distplot(y_train_poly,hist=False,color='b',label='Fitted Value',ax=ax1)
plt.title('Actual vs Fitted Value of train data in polynomial Regression')
plt.xlabel('Price')
plt.show('Properties')
plt.close()

# %%
#density plot to see the difference between the actual value and polynomial filled values
plt.figure(figsize=(12,10))
ax1=sns.distplot(y_test,hist=False,color='r',label='Actual Value')
sns.distplot(y_test_poly,hist=False,color='b',label='Fitted Value',ax=ax1)
plt.title('Actual vs Fitted Value of test data in Polynomial Regression')
plt.xlabel('Price')
plt.show('Properties')
plt.close()

# %%
mean_squared_error(y_test,y_test_poly)
# Out:
# 13589923.707858166

# %%
lm_poly.score(x_test_poly,y_test)
# Out:
# 0.7262026948276802
